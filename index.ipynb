# %% [markdown]
# # Managing your finaces using Python
#
# ## with beancount and fava
#
# <br>
# <br>
#
# #### Brian Ryall
# #### @polarmutex

# %% [markdown]
# # Backstory

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/86/Microsoft_Excel_2013_logo.svg/1200px-Microsoft_Excel_2013_logo.svg.png" width="100">

# %% [markdown]
# <img src="https://cdn.mos.cms.futurecdn.net/HCHyG47mRCD6By9Hthwsx4-1200-80.jpg" width="200">

# %% [markdown]
#  ![](https://upload.wikimedia.org/wikipedia/commons/d/d4/YNAB_logo.svg)

# %% [markdown]
# # Beancount Features
#
# * plaintext accounting
# * double-entry accounting
# * Reports
# * cli and python api
# * Great Investment support
# * Plugin architecture
# * Web interface with fava

# %% [markdown]
# # Installation
# ```bash
# pip install beancount
# pip install beancount-fava
# ```

# %% [markdown]
# # Source File
#
# <img src="source-file.png" width="1000">

# %% [markdown]
# # Transaction
#
#
# 2020-07-25&nbsp;&nbsp;&nbsp;&nbsp;txn&nbsp;&nbsp;&nbsp;&nbsp;"Coffee House"
#
# &nbsp;&nbsp;&nbsp;&nbsp;Liabilities:Credit-Card&nbsp;&nbsp;&nbsp;&nbsp;-5.15 USD
#
# &nbsp;&nbsp;&nbsp;&nbsp;Expenses:Coffee

# %% [markdown]
# # Transaction
#
#
# <span style="color:blue">**2020-07-25**</span>&nbsp;&nbsp;&nbsp;&nbsp;txn&nbsp;&nbsp;&nbsp;&nbsp;"Coffee House"
#
# &nbsp;&nbsp;&nbsp;&nbsp;Liabilities:Credit-Card&nbsp;&nbsp;&nbsp;&nbsp;-5.15 USD
#
# &nbsp;&nbsp;&nbsp;&nbsp;Expenses:Coffee
#
# ____
#
# Date in ISO format

# %% [markdown]
# # Transaction
#
#
# 2020-07-25&nbsp;&nbsp;&nbsp;&nbsp;<span style="color:blue">**txn**</span>&nbsp;&nbsp;&nbsp;&nbsp;"Coffee House"
#
# &nbsp;&nbsp;&nbsp;&nbsp;Liabilities:Credit-Card&nbsp;&nbsp;&nbsp;&nbsp;-5.15 USD
#
# &nbsp;&nbsp;&nbsp;&nbsp;Expenses:Coffee
#
# ___
#
# Flag
#
# - txn - transaction
# - \* - cleared
# - ! - pending

# %% [markdown]
# # Transaction
#
#
# 2020-07-25&nbsp;&nbsp;&nbsp;&nbsp;txn&nbsp;&nbsp;&nbsp;&nbsp;<span style="color:blue">**"Coffee House"**</span>
#
# &nbsp;&nbsp;&nbsp;&nbsp;Liabilities:Credit-Card&nbsp;&nbsp;&nbsp;&nbsp;-5.15 USD
#
# &nbsp;&nbsp;&nbsp;&nbsp;Expenses:Coffee
# ___
#
# Payee String

# %% [markdown]
# # Transaction
#
#
# 2020-07-25&nbsp;&nbsp;&nbsp;&nbsp;txn&nbsp;&nbsp;&nbsp;&nbsp;"Coffee House"
#
# &nbsp;&nbsp;&nbsp;&nbsp;<span style="color:blue">**Liabilities:Credit-Card**</span>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;-5.15 USD
#
# &nbsp;&nbsp;&nbsp;&nbsp;Expenses:Coffee
# ___
# Account (must start with one of the following)
# * Assets
# * Liabilities
# * Income
# * Expense
# * Equity

# %% [markdown]
# # Transaction
#
#
# 2020-07-25&nbsp;&nbsp;&nbsp;&nbsp;txn&nbsp;&nbsp;&nbsp;&nbsp;"Coffee House"
#
# &nbsp;&nbsp;&nbsp;&nbsp;Liabilities:Credit-Card&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span style="color:blue">**-5.15 USD**</span>
#
# &nbsp;&nbsp;&nbsp;&nbsp;Expenses:Coffee
#
# Amount of credit/debit with currency

# %% [markdown]
# # Directive
#
#
# 2020-07-25&nbsp;&nbsp;&nbsp;&nbsp;balance&nbsp;&nbsp;&nbsp;&nbsp;Assets:Checking&nbsp;&nbsp;&nbsp;&nbsp;1000.00 USD
#    ___
#
#    Input to specify Metadata and Options
#
#    * open/close
#    * balance
#    * note
#    * event
#    * options

# %% [markdown]
# # Loading Source File

# %%
from beancount import loader

filename = "example.beancount"
entries, errors, options_map = loader.load_file(filename)

entries
# Out:
# [Commodity(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 16, 'export': 'CASH', 'name': 'US Dollar'}, date=datetime.date(1792, 1, 1), currency='USD'),
#  Commodity(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 20, 'export': 'MUTF:VMMXX (MONEY:USD)'}, date=datetime.date(1900, 1, 1), currency='VMMXX'),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 65}, date=datetime.date(1980, 5, 12), account='Equity:Opening-Balances', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 66}, date=datetime.date(1980, 5, 12), account='Liabilities:AccountsPayable', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 917}, date=datetime.date(1980, 5, 12), account='Liabilities:US:Chase:Slate', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6125}, date=datetime.date(1980, 5, 12), account='Income:US:Federal:PreTax401k', currencies=['IRAUSD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6126}, date=datetime.date(1980, 5, 12), account='Assets:US:Federal:PreTax401k', currencies=['IRAUSD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6220}, date=datetime.date(1980, 5, 12), account='Expenses:Food:Groceries', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6221}, date=datetime.date(1980, 5, 12), account='Expenses:Food:Restaurant', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6222}, date=datetime.date(1980, 5, 12), account='Expenses:Food:Coffee', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6223}, date=datetime.date(1980, 5, 12), account='Expenses:Food:Alcohol', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6224}, date=datetime.date(1980, 5, 12), account='Expenses:Transport:Tram', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6225}, date=datetime.date(1980, 5, 12), account='Expenses:Home:Rent', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6226}, date=datetime.date(1980, 5, 12), account='Expenses:Home:Electricity', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6227}, date=datetime.date(1980, 5, 12), account='Expenses:Home:Internet', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6228}, date=datetime.date(1980, 5, 12), account='Expenses:Home:Phone', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6229}, date=datetime.date(1980, 5, 12), account='Expenses:Financial:Fees', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6230}, date=datetime.date(1980, 5, 12), account='Expenses:Financial:Commissions', currencies=None, booking=None),
#  Commodity(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 23, 'export': 'IGNORE', 'name': 'Employer Vacation Hours'}, date=datetime.date(1980, 5, 12), currency='VACHR'),
#  Commodity(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 27, 'export': 'IGNORE', 'name': 'US 401k and IRA Contributions'}, date=datetime.date(1980, 5, 12), currency='IRAUSD'),
#  Commodity(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 31, 'export': 'MUTF:VBMPX', 'name': 'Vanguard Total Bond Market Index Fund Institutional Plus Shares', 'price': 'USD:google/MUTF:VBMPX'}, date=datetime.date(1995, 9, 18), currency='VBMPX'),
#  Commodity(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 36, 'export': 'NYSEARCA:ITOT', 'name': 'iShares Core S&P Total U.S. Stock Market ETF', 'price': 'USD:google/NYSEARCA:ITOT'}, date=datetime.date(2004, 1, 20), currency='ITOT'),
#  Commodity(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 41, 'export': 'NYSEARCA:VHT', 'name': 'Vanguard Health Care ETF', 'price': 'USD:google/NYSEARCA:VHT'}, date=datetime.date(2004, 1, 26), currency='VHT'),
#  Commodity(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 46, 'export': 'NYSEARCA:GLD', 'name': 'SPDR Gold Trust (ETF)', 'price': 'USD:google/NYSEARCA:GLD'}, date=datetime.date(2004, 11, 1), currency='GLD'),
#  Commodity(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 51, 'export': 'NYSEARCA:VEA', 'name': 'Vanguard FTSE Developed Markets ETF', 'price': 'USD:google/NYSEARCA:VEA'}, date=datetime.date(2007, 7, 20), currency='VEA'),
#  Commodity(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 56, 'export': 'MUTF:RGAGX', 'name': 'American Funds The Growth Fund of America Class R-6', 'price': 'USD:google/MUTF:RGAGX'}, date=datetime.date(2009, 5, 1), currency='RGAGX'),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 72, 'address': '123 America Street, LargeTown, USA', 'institution': 'Bank of America', 'phone': '+1.012.345.6789'}, date=datetime.date(2013, 1, 1), account='Assets:US:BofA', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 76, 'account': '00234-48574897'}, date=datetime.date(2013, 1, 1), account='Assets:US:BofA:Checking', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3347}, date=datetime.date(2013, 1, 1), account='Assets:US:ETrade:Cash', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3348}, date=datetime.date(2013, 1, 1), account='Assets:US:ETrade:ITOT', currencies=['ITOT'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3349}, date=datetime.date(2013, 1, 1), account='Assets:US:ETrade:VEA', currencies=['VEA'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3350}, date=datetime.date(2013, 1, 1), account='Assets:US:ETrade:VHT', currencies=['VHT'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3351}, date=datetime.date(2013, 1, 1), account='Assets:US:ETrade:GLD', currencies=['GLD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3352}, date=datetime.date(2013, 1, 1), account='Income:US:ETrade:Gains', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3353}, date=datetime.date(2013, 1, 1), account='Income:US:ETrade:Dividends', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3699, 'number': '882882'}, date=datetime.date(2013, 1, 1), account='Assets:US:Vanguard:VBMPX', currencies=['VBMPX'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3701, 'number': '882882'}, date=datetime.date(2013, 1, 1), account='Assets:US:Vanguard:RGAGX', currencies=['RGAGX'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3703, 'address': 'P.O. Box 1110, Valley Forge, PA 19482-1110', 'institution': 'Vanguard Group', 'phone': '+1.800.523.1188'}, date=datetime.date(2013, 1, 1), account='Assets:US:Vanguard', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3707}, date=datetime.date(2013, 1, 1), account='Income:US:Hoogle:Match401k', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3708, 'number': '882882'}, date=datetime.date(2013, 1, 1), account='Assets:US:Vanguard:Cash', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4615}, date=datetime.date(2013, 1, 1), account='Income:US:Hoogle:Salary', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4616}, date=datetime.date(2013, 1, 1), account='Income:US:Hoogle:GroupTermLife', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4617}, date=datetime.date(2013, 1, 1), account='Income:US:Hoogle:Vacation', currencies=['VACHR'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4618}, date=datetime.date(2013, 1, 1), account='Assets:US:Hoogle:Vacation', currencies=['VACHR'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4619}, date=datetime.date(2013, 1, 1), account='Expenses:Vacation', currencies=['VACHR'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4620}, date=datetime.date(2013, 1, 1), account='Expenses:Health:Life:GroupTermLife', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4621}, date=datetime.date(2013, 1, 1), account='Expenses:Health:Medical:Insurance', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4622}, date=datetime.date(2013, 1, 1), account='Expenses:Health:Dental:Insurance', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4623}, date=datetime.date(2013, 1, 1), account='Expenses:Health:Vision:Insurance', currencies=None, booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6132}, date=datetime.date(2013, 1, 1), account='Expenses:Taxes:Y2013:US:Federal:PreTax401k', currencies=['IRAUSD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6133}, date=datetime.date(2013, 1, 1), account='Expenses:Taxes:Y2013:US:Medicare', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6134}, date=datetime.date(2013, 1, 1), account='Expenses:Taxes:Y2013:US:Federal', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6135}, date=datetime.date(2013, 1, 1), account='Expenses:Taxes:Y2013:US:CityNYC', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6136}, date=datetime.date(2013, 1, 1), account='Expenses:Taxes:Y2013:US:SDI', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6137}, date=datetime.date(2013, 1, 1), account='Expenses:Taxes:Y2013:US:State', currencies=['USD'], booking=None),
#  Open(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6138}, date=datetime.date(2013, 1, 1), account='Expenses:Taxes:Y2013:US:SocSec', currencies=['USD'], booking=None),
#  Balance(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6140}, date=datetime.date(2013, 1, 1), account='Assets:US:Federal:PreTax401k', amount=0 IRAUSD, tolerance=None, diff_amount=None),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 79, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 1), flag='*', payee=None, narration='Opening Balance for checking account', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:BofA:Checking', units=3219.17 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 80}), Posting(account='Equity:Opening-Balances', units=-3219.17 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 81})]),
#  Event(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4625}, date=datetime.date(2013, 1, 1), type='employer', description='Hoogle, 1600 Amphibious Parkway, River View, CA'),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6142, '__tolerances__': {}}, date=datetime.date(2013, 1, 1), flag='*', payee=None, narration='Allowed contributions for one year', tags=frozenset(), links=frozenset(), postings=[Posting(account='Income:US:Federal:PreTax401k', units=-17500 IRAUSD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6143}), Posting(account='Assets:US:Federal:PreTax401k', units=17500 IRAUSD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6144})]),
#  Balance(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 83}, date=datetime.date(2013, 1, 2), account='Assets:US:BofA:Checking', amount=3219.17 USD, tolerance=None, diff_amount=None),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4627, '__tolerances__': {'USD': Decimal('0.005'), 'IRAUSD': Decimal('0.005')}}, date=datetime.date(2013, 1, 3), flag='*', payee='Hoogle', narration='Payroll', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:BofA:Checking', units=1350.60 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4628}), Posting(account='Assets:US:Vanguard:Cash', units=1200.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4629}), Posting(account='Income:US:Hoogle:Salary', units=-4615.38 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4632}), Posting(account='Income:US:Hoogle:GroupTermLife', units=-24.32 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4633}), Posting(account='Expenses:Health:Life:GroupTermLife', units=24.32 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4634}), Posting(account='Expenses:Health:Dental:Insurance', units=2.90 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4635}), Posting(account='Expenses:Health:Medical:Insurance', units=27.38 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4636}), Posting(account='Expenses:Health:Vision:Insurance', units=42.30 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4637}), Posting(account='Expenses:Taxes:Y2013:US:Medicare', units=106.62 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4638}), Posting(account='Expenses:Taxes:Y2013:US:Federal', units=1062.92 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4639}), Posting(account='Expenses:Taxes:Y2013:US:State', units=365.08 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4640}), Posting(account='Expenses:Taxes:Y2013:US:CityNYC', units=174.92 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4641}), Posting(account='Expenses:Taxes:Y2013:US:SDI', units=1.12 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4642}), Posting(account='Expenses:Taxes:Y2013:US:SocSec', units=281.54 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4643}), Posting(account='Assets:US:Federal:PreTax401k', units=-1200.00 IRAUSD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4630}), Posting(account='Expenses:Taxes:Y2013:US:Federal:PreTax401k', units=1200.00 IRAUSD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4631}), Posting(account='Assets:US:Hoogle:Vacation', units=5 VACHR, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4644}), Posting(account='Income:US:Hoogle:Vacation', units=-5 VACHR, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4645})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 85, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 4), flag='*', payee='BANK FEES', narration='Monthly bank fee', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:BofA:Checking', units=-4.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 86}), Posting(account='Expenses:Financial:Fees', units=4.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 87})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3711, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 4), flag='*', payee=None, narration='Employer match for contribution', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:Cash', units=600.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3712}), Posting(account='Income:US:Hoogle:Match401k', units=-600.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3713})]),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6236}, date=datetime.date(2013, 1, 4), currency='VBMPX', amount=70.47 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6237}, date=datetime.date(2013, 1, 4), currency='RGAGX', amount=152.91 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6238}, date=datetime.date(2013, 1, 4), currency='ITOT', amount=94.42 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6239}, date=datetime.date(2013, 1, 4), currency='VEA', amount=60.87 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6240}, date=datetime.date(2013, 1, 4), currency='VHT', amount=53.18 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6241}, date=datetime.date(2013, 1, 4), currency='GLD', amount=158.44 USD),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 919, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 5), flag='*', payee='Kin Soy', narration='Eating out with Bill', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-40.88 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 920}), Posting(account='Expenses:Food:Restaurant', units=40.88 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 921})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 89, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 6), flag='*', payee='RiverBank Properties', narration='Paying the rent', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:BofA:Checking', units=-2400.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 90}), Posting(account='Expenses:Home:Rent', units=2400.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 91})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3715, '__tolerances__': {'VBMPX': Decimal('0.0005'), 'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 7), flag='*', payee=None, narration='Investing 40% of cash in VBMPX', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:VBMPX', units=6.811 VBMPX, cost=Cost(number=Decimal('70.47'), currency='USD', date=datetime.date(2013, 1, 7), label=None), price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3716}), Posting(account='Assets:US:Vanguard:Cash', units=-479.97 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3717})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3719, '__tolerances__': {'RGAGX': Decimal('0.0005'), 'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 7), flag='*', payee=None, narration='Investing 60% of cash in RGAGX', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:RGAGX', units=4.709 RGAGX, cost=Cost(number=Decimal('152.91'), currency='USD', date=datetime.date(2013, 1, 7), label=None), price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3720}), Posting(account='Assets:US:Vanguard:Cash', units=-720.05 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3721})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3723, '__tolerances__': {'VBMPX': Decimal('0.0005'), 'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 7), flag='*', payee=None, narration='Investing 40% of cash in VBMPX', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:VBMPX', units=3.406 VBMPX, cost=Cost(number=Decimal('70.47'), currency='USD', date=datetime.date(2013, 1, 7), label=None), price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3724}), Posting(account='Assets:US:Vanguard:Cash', units=-240.02 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3725})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3727, '__tolerances__': {'RGAGX': Decimal('0.0005'), 'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 7), flag='*', payee=None, narration='Investing 60% of cash in RGAGX', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:RGAGX', units=2.354 RGAGX, cost=Cost(number=Decimal('152.91'), currency='USD', date=datetime.date(2013, 1, 7), label=None), price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3728}), Posting(account='Assets:US:Vanguard:Cash', units=-359.95 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3729})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 923, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 8), flag='*', payee='Rose Flower', narration='Eating out alone', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-23.05 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 924}), Posting(account='Expenses:Food:Restaurant', units=23.05 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 925})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 93, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 9), flag='*', payee='EDISON POWER', narration='', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:BofA:Checking', units=-65.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 94}), Posting(account='Expenses:Home:Electricity', units=65.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 95})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 927, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 9), flag='*', payee='Jewel of Morroco', narration='Eating out with Bill', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-35.28 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 928}), Posting(account='Expenses:Food:Restaurant', units=35.28 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 929})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 931, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 9), flag='*', payee='Chase:Slate', narration='Paying off credit card', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=99.21 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 932}), Posting(account='Assets:US:BofA:Checking', units=-99.21 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 933})]),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6242}, date=datetime.date(2013, 1, 11), currency='VBMPX', amount=70.88 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6243}, date=datetime.date(2013, 1, 11), currency='RGAGX', amount=149.48 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6244}, date=datetime.date(2013, 1, 11), currency='ITOT', amount=94.73 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6245}, date=datetime.date(2013, 1, 11), currency='VEA', amount=60.35 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6246}, date=datetime.date(2013, 1, 11), currency='VHT', amount=53.89 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6247}, date=datetime.date(2013, 1, 11), currency='GLD', amount=160.14 USD),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 935, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 14), flag='*', payee='Kin Soy', narration='Eating out ', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-25.84 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 936}), Posting(account='Expenses:Food:Restaurant', units=25.84 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 937})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 939, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 15), flag='*', payee='Farmer Fresh', narration='Buying groceries', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-82.22 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 940}), Posting(account='Expenses:Food:Groceries', units=82.22 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 941})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 943, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 17), flag='*', payee='Jewel of Morroco', narration='Eating out with Joe', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-36.73 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 944}), Posting(account='Expenses:Food:Restaurant', units=36.73 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 945})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4647, '__tolerances__': {'USD': Decimal('0.005'), 'IRAUSD': Decimal('0.005')}}, date=datetime.date(2013, 1, 17), flag='*', payee='Hoogle', narration='Payroll', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:BofA:Checking', units=1350.60 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4648}), Posting(account='Assets:US:Vanguard:Cash', units=1200.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4649}), Posting(account='Income:US:Hoogle:Salary', units=-4615.38 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4652}), Posting(account='Income:US:Hoogle:GroupTermLife', units=-24.32 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4653}), Posting(account='Expenses:Health:Life:GroupTermLife', units=24.32 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4654}), Posting(account='Expenses:Health:Dental:Insurance', units=2.90 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4655}), Posting(account='Expenses:Health:Medical:Insurance', units=27.38 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4656}), Posting(account='Expenses:Health:Vision:Insurance', units=42.30 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4657}), Posting(account='Expenses:Taxes:Y2013:US:Medicare', units=106.62 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4658}), Posting(account='Expenses:Taxes:Y2013:US:Federal', units=1062.92 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4659}), Posting(account='Expenses:Taxes:Y2013:US:State', units=365.08 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4660}), Posting(account='Expenses:Taxes:Y2013:US:CityNYC', units=174.92 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4661}), Posting(account='Expenses:Taxes:Y2013:US:SDI', units=1.12 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4662}), Posting(account='Expenses:Taxes:Y2013:US:SocSec', units=281.54 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4663}), Posting(account='Assets:US:Federal:PreTax401k', units=-1200.00 IRAUSD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4650}), Posting(account='Expenses:Taxes:Y2013:US:Federal:PreTax401k', units=1200.00 IRAUSD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4651}), Posting(account='Assets:US:Hoogle:Vacation', units=5 VACHR, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4664}), Posting(account='Income:US:Hoogle:Vacation', units=-5 VACHR, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4665})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3731, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 18), flag='*', payee=None, narration='Employer match for contribution', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:Cash', units=600.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3732}), Posting(account='Income:US:Hoogle:Match401k', units=-600.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3733})]),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6248}, date=datetime.date(2013, 1, 18), currency='VBMPX', amount=71.11 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6249}, date=datetime.date(2013, 1, 18), currency='RGAGX', amount=148.76 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6250}, date=datetime.date(2013, 1, 18), currency='ITOT', amount=94.85 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6251}, date=datetime.date(2013, 1, 18), currency='VEA', amount=60.07 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6252}, date=datetime.date(2013, 1, 18), currency='VHT', amount=53.14 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6253}, date=datetime.date(2013, 1, 18), currency='GLD', amount=157.93 USD),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 97, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 20), flag='*', payee='Verizon Wireless', narration='', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:BofA:Checking', units=-69.82 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 98}), Posting(account='Expenses:Home:Phone', units=69.82 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 99})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 947, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 21), flag='*', payee='Cafe Modagor', narration='Eating out with Bill', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-28.11 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 948}), Posting(account='Expenses:Food:Restaurant', units=28.11 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 949})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 951, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 21), flag='*', payee='Onion Market', narration='Buying groceries', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-73.58 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 952}), Posting(account='Expenses:Food:Groceries', units=73.58 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 953})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3735, '__tolerances__': {'VBMPX': Decimal('0.0005'), 'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 21), flag='*', payee=None, narration='Investing 40% of cash in VBMPX', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:VBMPX', units=6.750 VBMPX, cost=Cost(number=Decimal('71.11'), currency='USD', date=datetime.date(2013, 1, 21), label=None), price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3736}), Posting(account='Assets:US:Vanguard:Cash', units=-479.99 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3737})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3739, '__tolerances__': {'RGAGX': Decimal('0.0005'), 'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 21), flag='*', payee=None, narration='Investing 60% of cash in RGAGX', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:RGAGX', units=4.840 RGAGX, cost=Cost(number=Decimal('148.76'), currency='USD', date=datetime.date(2013, 1, 21), label=None), price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3740}), Posting(account='Assets:US:Vanguard:Cash', units=-720.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3741})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3743, '__tolerances__': {'VBMPX': Decimal('0.0005'), 'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 21), flag='*', payee=None, narration='Investing 40% of cash in VBMPX', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:VBMPX', units=3.375 VBMPX, cost=Cost(number=Decimal('71.11'), currency='USD', date=datetime.date(2013, 1, 21), label=None), price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3744}), Posting(account='Assets:US:Vanguard:Cash', units=-240.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3745})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3747, '__tolerances__': {'RGAGX': Decimal('0.0005'), 'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 21), flag='*', payee=None, narration='Investing 60% of cash in RGAGX', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:RGAGX', units=2.420 RGAGX, cost=Cost(number=Decimal('148.76'), currency='USD', date=datetime.date(2013, 1, 21), label=None), price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3748}), Posting(account='Assets:US:Vanguard:Cash', units=-360.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 3749})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 101, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 22), flag='*', payee='Wine-Tarner Cable', narration='', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:BofA:Checking', units=-79.85 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 102}), Posting(account='Expenses:Home:Internet', units=79.85 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 103})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 955, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 22), flag='*', payee='Chichipotle', narration='Eating out alone', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-21.12 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 956}), Posting(account='Expenses:Food:Restaurant', units=21.12 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 957})]),
#  Balance(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 105}, date=datetime.date(2013, 1, 23), account='Assets:US:BofA:Checking', amount=3202.49 USD, tolerance=None, diff_amount=None),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 959, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 24), flag='*', payee='Chichipotle', narration='Eating out after work', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-41.63 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 960}), Posting(account='Expenses:Food:Restaurant', units=41.63 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 961})]),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6254}, date=datetime.date(2013, 1, 25), currency='VBMPX', amount=71.37 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6255}, date=datetime.date(2013, 1, 25), currency='RGAGX', amount=150.29 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6256}, date=datetime.date(2013, 1, 25), currency='ITOT', amount=93.59 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6257}, date=datetime.date(2013, 1, 25), currency='VEA', amount=61.09 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6258}, date=datetime.date(2013, 1, 25), currency='VHT', amount=54.92 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6259}, date=datetime.date(2013, 1, 25), currency='GLD', amount=157.27 USD),
#  Balance(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 963}, date=datetime.date(2013, 1, 26), account='Liabilities:US:Chase:Slate', amount=-309.23 USD, tolerance=None, diff_amount=None),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 965, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 27), flag='*', payee='Good Moods Market', narration='Buying groceries', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-85.50 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 966}), Posting(account='Expenses:Food:Groceries', units=85.50 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 967})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 969, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2013, 1, 29), flag='*', payee='Cafe Modagor', narration='Eating out ', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-18.89 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 970}), Posting(account='Expenses:Food:Restaurant', units=18.89 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 971})]),
# ...
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6617}, date=datetime.date(2014, 3, 21), currency='VEA', amount=52.24 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6618}, date=datetime.date(2014, 3, 21), currency='VHT', amount=48.21 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6619}, date=datetime.date(2014, 3, 21), currency='GLD', amount=144.16 USD),
#  Balance(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 423}, date=datetime.date(2014, 3, 22), account='Assets:US:BofA:Checking', amount=5761.39 USD, tolerance=None, diff_amount=None),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 425, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2014, 3, 22), flag='*', payee='Wine-Tarner Cable', narration='', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:BofA:Checking', units=-80.01 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 426}), Posting(account='Expenses:Home:Internet', units=80.01 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 427})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 2001, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2014, 3, 23), flag='*', payee='Jewel of Morroco', narration='Eating out after work', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-18.25 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 2002}), Posting(account='Expenses:Food:Restaurant', units=18.25 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 2003})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 2005, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2014, 3, 25), flag='*', payee='Cafe Modagor', narration='Eating out with work buddies', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-30.26 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 2006}), Posting(account='Expenses:Food:Restaurant', units=30.26 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 2007})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6146, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2014, 3, 25), flag='*', payee=None, narration='Filing taxes for 2013', tags=frozenset(), links=frozenset(), postings=[Posting(account='Expenses:Taxes:Y2013:US:Federal', units=425.68 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6147}), Posting(account='Expenses:Taxes:Y2013:US:State', units=376.64 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6148}), Posting(account='Liabilities:AccountsPayable', units=-802.32 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6149})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6151, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2014, 3, 25), flag='*', payee=None, narration='FEDERAL TAXPYMT', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:BofA:Checking', units=-425.68 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6152}), Posting(account='Liabilities:AccountsPayable', units=425.68 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6153})]),
#  Balance(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 2009}, date=datetime.date(2014, 3, 27), account='Liabilities:US:Chase:Slate', amount=-1835.69 USD, tolerance=None, diff_amount=None),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5245, '__tolerances__': {'USD': Decimal('0.005'), 'IRAUSD': Decimal('0.005')}}, date=datetime.date(2014, 3, 27), flag='*', payee='Hoogle', narration='Payroll', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:BofA:Checking', units=1350.60 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5246}), Posting(account='Assets:US:Vanguard:Cash', units=1200.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5247}), Posting(account='Income:US:Hoogle:Salary', units=-4615.38 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5250}), Posting(account='Income:US:Hoogle:GroupTermLife', units=-24.32 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5251}), Posting(account='Expenses:Health:Life:GroupTermLife', units=24.32 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5252}), Posting(account='Expenses:Health:Dental:Insurance', units=2.90 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5253}), Posting(account='Expenses:Health:Medical:Insurance', units=27.38 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5254}), Posting(account='Expenses:Health:Vision:Insurance', units=42.30 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5255}), Posting(account='Expenses:Taxes:Y2014:US:Medicare', units=106.62 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5256}), Posting(account='Expenses:Taxes:Y2014:US:Federal', units=1062.92 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5257}), Posting(account='Expenses:Taxes:Y2014:US:State', units=365.08 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5258}), Posting(account='Expenses:Taxes:Y2014:US:CityNYC', units=174.92 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5259}), Posting(account='Expenses:Taxes:Y2014:US:SDI', units=1.12 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5260}), Posting(account='Expenses:Taxes:Y2014:US:SocSec', units=281.54 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5261}), Posting(account='Assets:US:Federal:PreTax401k', units=-1200.00 IRAUSD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5248}), Posting(account='Expenses:Taxes:Y2014:US:Federal:PreTax401k', units=1200.00 IRAUSD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5249}), Posting(account='Assets:US:Hoogle:Vacation', units=5 VACHR, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5262}), Posting(account='Income:US:Hoogle:Vacation', units=-5 VACHR, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 5263})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 2011, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2014, 3, 28), flag='*', payee='Onion Market', narration='Buying groceries', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-59.38 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 2012}), Posting(account='Expenses:Food:Groceries', units=59.38 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 2013})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4131, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2014, 3, 28), flag='*', payee=None, narration='Employer match for contribution', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:Cash', units=600.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4132}), Posting(account='Income:US:Hoogle:Match401k', units=-600.00 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4133})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6155, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2014, 3, 28), flag='*', payee=None, narration='STATE TAX & FINANC PYMT', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:BofA:Checking', units=-376.64 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6156}), Posting(account='Liabilities:AccountsPayable', units=376.64 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6157})]),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6620}, date=datetime.date(2014, 3, 28), currency='VBMPX', amount=75.86 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6621}, date=datetime.date(2014, 3, 28), currency='RGAGX', amount=162.12 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6622}, date=datetime.date(2014, 3, 28), currency='ITOT', amount=103.99 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6623}, date=datetime.date(2014, 3, 28), currency='VEA', amount=51.32 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6624}, date=datetime.date(2014, 3, 28), currency='VHT', amount=48.46 USD),
#  Price(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 6625}, date=datetime.date(2014, 3, 28), currency='GLD', amount=142.12 USD),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 2015, '__tolerances__': {'USD': Decimal('0.005')}}, date=datetime.date(2014, 3, 30), flag='*', payee='Uncle Boons', narration='Eating out with Bill', tags=frozenset(), links=frozenset(), postings=[Posting(account='Liabilities:US:Chase:Slate', units=-29.43 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 2016}), Posting(account='Expenses:Food:Restaurant', units=29.43 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 2017})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4135, '__tolerances__': {'VBMPX': Decimal('0.0005'), 'USD': Decimal('0.005')}}, date=datetime.date(2014, 3, 31), flag='*', payee=None, narration='Investing 40% of cash in VBMPX', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:VBMPX', units=6.327 VBMPX, cost=Cost(number=Decimal('75.86'), currency='USD', date=datetime.date(2014, 3, 31), label=None), price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4136}), Posting(account='Assets:US:Vanguard:Cash', units=-479.97 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4137})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4139, '__tolerances__': {'RGAGX': Decimal('0.0005'), 'USD': Decimal('0.005')}}, date=datetime.date(2014, 3, 31), flag='*', payee=None, narration='Investing 60% of cash in RGAGX', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:RGAGX', units=4.441 RGAGX, cost=Cost(number=Decimal('162.12'), currency='USD', date=datetime.date(2014, 3, 31), label=None), price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4140}), Posting(account='Assets:US:Vanguard:Cash', units=-719.97 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4141})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4143, '__tolerances__': {'VBMPX': Decimal('0.0005'), 'USD': Decimal('0.005')}}, date=datetime.date(2014, 3, 31), flag='*', payee=None, narration='Investing 40% of cash in VBMPX', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:VBMPX', units=3.164 VBMPX, cost=Cost(number=Decimal('75.86'), currency='USD', date=datetime.date(2014, 3, 31), label=None), price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4144}), Posting(account='Assets:US:Vanguard:Cash', units=-240.02 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4145})]),
#  Transaction(meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4147, '__tolerances__': {'RGAGX': Decimal('0.0005'), 'USD': Decimal('0.005')}}, date=datetime.date(2014, 3, 31), flag='*', payee=None, narration='Investing 60% of cash in RGAGX', tags=frozenset(), links=frozenset(), postings=[Posting(account='Assets:US:Vanguard:RGAGX', units=2.221 RGAGX, cost=Cost(number=Decimal('162.12'), currency='USD', date=datetime.date(2014, 3, 31), label=None), price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4148}), Posting(account='Assets:US:Vanguard:Cash', units=-360.07 USD, cost=None, price=None, flag=None, meta={'filename': '/Users/brian/dev/manage-finances-using-python/example.beancount', 'lineno': 4149})]),
#  ...]

# %%
from beancount.core.data import filter_txns

# Now we can just loop over the transactions and do the processing we want ...

sum = 0
for entry in filter_txns(entries):
    for posting in entry.postings:
        if "Food" in posting.account:
            # As long as same curreny, API exists to convert
            sum += posting.units[0]
sum
# Out:
# Decimal('19611.20')

# %% [markdown]
# # Beancount Query Language
# Account Balances

# %%
from beancount.query import query

query_str = r"""
SELECT
  date, account, position, balance 
WHERE 
  account ~ 'Checking';
"""
rtypes, rrows = query.run_query(entries,options_map,query_str)
rrows
# Out:
# [ResultRow(date=datetime.date(2013, 1, 1), account='Assets:US:BofA:Checking', position=3219.17 USD, balance=(3219.17 USD)),
#  ResultRow(date=datetime.date(2013, 1, 3), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(4569.77 USD)),
#  ResultRow(date=datetime.date(2013, 1, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(4565.77 USD)),
#  ResultRow(date=datetime.date(2013, 1, 6), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(2165.77 USD)),
#  ResultRow(date=datetime.date(2013, 1, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(2100.77 USD)),
#  ResultRow(date=datetime.date(2013, 1, 9), account='Assets:US:BofA:Checking', position=-99.21 USD, balance=(2001.56 USD)),
#  ResultRow(date=datetime.date(2013, 1, 17), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(3352.16 USD)),
#  ResultRow(date=datetime.date(2013, 1, 20), account='Assets:US:BofA:Checking', position=-69.82 USD, balance=(3282.34 USD)),
#  ResultRow(date=datetime.date(2013, 1, 22), account='Assets:US:BofA:Checking', position=-79.85 USD, balance=(3202.49 USD)),
#  ResultRow(date=datetime.date(2013, 1, 31), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(4553.09 USD)),
#  ResultRow(date=datetime.date(2013, 2, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(4549.09 USD)),
#  ResultRow(date=datetime.date(2013, 2, 5), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(2149.09 USD)),
#  ResultRow(date=datetime.date(2013, 2, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(2084.09 USD)),
#  ResultRow(date=datetime.date(2013, 2, 10), account='Assets:US:BofA:Checking', position=-650.97 USD, balance=(1433.12 USD)),
#  ResultRow(date=datetime.date(2013, 2, 14), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(2783.72 USD)),
#  ResultRow(date=datetime.date(2013, 2, 20), account='Assets:US:BofA:Checking', position=-46.32 USD, balance=(2737.40 USD)),
#  ResultRow(date=datetime.date(2013, 2, 22), account='Assets:US:BofA:Checking', position=-79.97 USD, balance=(2657.43 USD)),
#  ResultRow(date=datetime.date(2013, 2, 28), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(4008.03 USD)),
#  ResultRow(date=datetime.date(2013, 3, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(4004.03 USD)),
#  ResultRow(date=datetime.date(2013, 3, 4), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(1604.03 USD)),
#  ResultRow(date=datetime.date(2013, 3, 7), account='Assets:US:BofA:Checking', position=-583.82 USD, balance=(1020.21 USD)),
#  ResultRow(date=datetime.date(2013, 3, 8), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(955.21 USD)),
#  ResultRow(date=datetime.date(2013, 3, 14), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(2305.81 USD)),
#  ResultRow(date=datetime.date(2013, 3, 19), account='Assets:US:BofA:Checking', position=-76.81 USD, balance=(2229.00 USD)),
#  ResultRow(date=datetime.date(2013, 3, 22), account='Assets:US:BofA:Checking', position=-80.00 USD, balance=(2149.00 USD)),
#  ResultRow(date=datetime.date(2013, 3, 28), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(3499.60 USD)),
#  ResultRow(date=datetime.date(2013, 4, 3), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(1099.60 USD)),
#  ResultRow(date=datetime.date(2013, 4, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(1095.60 USD)),
#  ResultRow(date=datetime.date(2013, 4, 8), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(1030.60 USD)),
#  ResultRow(date=datetime.date(2013, 4, 11), account='Assets:US:BofA:Checking', position=-747.16 USD, balance=(283.44 USD)),
#  ResultRow(date=datetime.date(2013, 4, 11), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(1634.04 USD)),
#  ResultRow(date=datetime.date(2013, 4, 18), account='Assets:US:BofA:Checking', position=-63.51 USD, balance=(1570.53 USD)),
#  ResultRow(date=datetime.date(2013, 4, 22), account='Assets:US:BofA:Checking', position=-80.19 USD, balance=(1490.34 USD)),
#  ResultRow(date=datetime.date(2013, 4, 25), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(2840.94 USD)),
#  ResultRow(date=datetime.date(2013, 5, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(2836.94 USD)),
#  ResultRow(date=datetime.date(2013, 5, 4), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(436.94 USD)),
#  ResultRow(date=datetime.date(2013, 5, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(371.94 USD)),
#  ResultRow(date=datetime.date(2013, 5, 9), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(1722.54 USD)),
#  ResultRow(date=datetime.date(2013, 5, 11), account='Assets:US:BofA:Checking', position=-533.14 USD, balance=(1189.40 USD)),
#  ResultRow(date=datetime.date(2013, 5, 19), account='Assets:US:BofA:Checking', position=-56.07 USD, balance=(1133.33 USD)),
#  ResultRow(date=datetime.date(2013, 5, 22), account='Assets:US:BofA:Checking', position=-79.93 USD, balance=(1053.40 USD)),
#  ResultRow(date=datetime.date(2013, 5, 23), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(2404.00 USD)),
#  ResultRow(date=datetime.date(2013, 6, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(2400.00 USD)),
#  ResultRow(date=datetime.date(2013, 6, 5), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=()),
#  ResultRow(date=datetime.date(2013, 6, 6), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(1350.60 USD)),
#  ResultRow(date=datetime.date(2013, 6, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(1285.60 USD)),
#  ResultRow(date=datetime.date(2013, 6, 9), account='Assets:US:BofA:Checking', position=-629.87 USD, balance=(655.73 USD)),
#  ResultRow(date=datetime.date(2013, 6, 19), account='Assets:US:BofA:Checking', position=-59.21 USD, balance=(596.52 USD)),
#  ResultRow(date=datetime.date(2013, 6, 20), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(1947.12 USD)),
#  ResultRow(date=datetime.date(2013, 6, 22), account='Assets:US:BofA:Checking', position=-79.86 USD, balance=(1867.26 USD)),
#  ResultRow(date=datetime.date(2013, 7, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(1863.26 USD)),
#  ResultRow(date=datetime.date(2013, 7, 4), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(3213.86 USD)),
#  ResultRow(date=datetime.date(2013, 7, 6), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(813.86 USD)),
#  ResultRow(date=datetime.date(2013, 7, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(748.86 USD)),
#  ResultRow(date=datetime.date(2013, 7, 9), account='Assets:US:BofA:Checking', position=-182.57 USD, balance=(566.29 USD)),
#  ResultRow(date=datetime.date(2013, 7, 18), account='Assets:US:BofA:Checking', position=-50.68 USD, balance=(515.61 USD)),
#  ResultRow(date=datetime.date(2013, 7, 18), account='Assets:US:BofA:Checking', position=1850.60 USD, balance=(2366.21 USD)),
#  ResultRow(date=datetime.date(2013, 7, 23), account='Assets:US:BofA:Checking', position=-80.17 USD, balance=(2286.04 USD)),
#  ResultRow(date=datetime.date(2013, 8, 1), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(4836.64 USD)),
#  ResultRow(date=datetime.date(2013, 8, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(4832.64 USD)),
#  ResultRow(date=datetime.date(2013, 8, 4), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(2432.64 USD)),
#  ResultRow(date=datetime.date(2013, 8, 8), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(2367.64 USD)),
#  ResultRow(date=datetime.date(2013, 8, 9), account='Assets:US:BofA:Checking', position=-534.53 USD, balance=(1833.11 USD)),
#  ResultRow(date=datetime.date(2013, 8, 15), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(4383.71 USD)),
#  ResultRow(date=datetime.date(2013, 8, 16), account='Assets:US:BofA:Checking', position=-3000 USD, balance=(1383.71 USD)),
#  ResultRow(date=datetime.date(2013, 8, 20), account='Assets:US:BofA:Checking', position=-61.29 USD, balance=(1322.42 USD)),
#  ResultRow(date=datetime.date(2013, 8, 21), account='Assets:US:BofA:Checking', position=-79.98 USD, balance=(1242.44 USD)),
#  ResultRow(date=datetime.date(2013, 8, 29), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(3793.04 USD)),
#  ResultRow(date=datetime.date(2013, 9, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(3789.04 USD)),
#  ResultRow(date=datetime.date(2013, 9, 5), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(1389.04 USD)),
#  ResultRow(date=datetime.date(2013, 9, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(1324.04 USD)),
#  ResultRow(date=datetime.date(2013, 9, 11), account='Assets:US:BofA:Checking', position=-756.85 USD, balance=(567.19 USD)),
#  ResultRow(date=datetime.date(2013, 9, 12), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(3117.79 USD)),
#  ResultRow(date=datetime.date(2013, 9, 19), account='Assets:US:BofA:Checking', position=-81.85 USD, balance=(3035.94 USD)),
#  ResultRow(date=datetime.date(2013, 9, 22), account='Assets:US:BofA:Checking', position=-80.02 USD, balance=(2955.92 USD)),
#  ResultRow(date=datetime.date(2013, 9, 26), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(5506.52 USD)),
#  ResultRow(date=datetime.date(2013, 10, 3), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(3106.52 USD)),
#  ResultRow(date=datetime.date(2013, 10, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(3102.52 USD)),
#  ResultRow(date=datetime.date(2013, 10, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(3037.52 USD)),
#  ResultRow(date=datetime.date(2013, 10, 9), account='Assets:US:BofA:Checking', position=-611.54 USD, balance=(2425.98 USD)),
#  ResultRow(date=datetime.date(2013, 10, 10), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(4976.58 USD)),
#  ResultRow(date=datetime.date(2013, 10, 11), account='Assets:US:BofA:Checking', position=-4500 USD, balance=(476.58 USD)),
#  ResultRow(date=datetime.date(2013, 10, 18), account='Assets:US:BofA:Checking', position=-76.78 USD, balance=(399.80 USD)),
#  ResultRow(date=datetime.date(2013, 10, 21), account='Assets:US:BofA:Checking', position=-79.97 USD, balance=(319.83 USD)),
#  ResultRow(date=datetime.date(2013, 10, 24), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(2870.43 USD)),
#  ResultRow(date=datetime.date(2013, 11, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(2866.43 USD)),
#  ResultRow(date=datetime.date(2013, 11, 5), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(466.43 USD)),
#  ResultRow(date=datetime.date(2013, 11, 7), account='Assets:US:BofA:Checking', position=-584.37 USD, balance=(-117.94 USD)),
#  ResultRow(date=datetime.date(2013, 11, 7), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(2432.66 USD)),
#  ResultRow(date=datetime.date(2013, 11, 8), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(2367.66 USD)),
#  ResultRow(date=datetime.date(2013, 11, 19), account='Assets:US:BofA:Checking', position=-89.68 USD, balance=(2277.98 USD)),
#  ResultRow(date=datetime.date(2013, 11, 21), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(4828.58 USD)),
#  ResultRow(date=datetime.date(2013, 11, 23), account='Assets:US:BofA:Checking', position=-79.83 USD, balance=(4748.75 USD)),
#  ResultRow(date=datetime.date(2013, 12, 3), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(2348.75 USD)),
#  ResultRow(date=datetime.date(2013, 12, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(2344.75 USD)),
#  ResultRow(date=datetime.date(2013, 12, 5), account='Assets:US:BofA:Checking', position=2589.06 USD, balance=(4933.81 USD)),
#  ResultRow(date=datetime.date(2013, 12, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(4868.81 USD)),
#  ResultRow(date=datetime.date(2013, 12, 9), account='Assets:US:BofA:Checking', position=-742.74 USD, balance=(4126.07 USD)),
#  ResultRow(date=datetime.date(2013, 12, 19), account='Assets:US:BofA:Checking', position=2832.14 USD, balance=(6958.21 USD)),
#  ResultRow(date=datetime.date(2013, 12, 20), account='Assets:US:BofA:Checking', position=-39.70 USD, balance=(6918.51 USD)),
#  ResultRow(date=datetime.date(2013, 12, 23), account='Assets:US:BofA:Checking', position=-79.90 USD, balance=(6838.61 USD)),
#  ResultRow(date=datetime.date(2014, 1, 2), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(8189.21 USD)),
#  ResultRow(date=datetime.date(2014, 1, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(8185.21 USD)),
#  ResultRow(date=datetime.date(2014, 1, 4), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(5785.21 USD)),
#  ResultRow(date=datetime.date(2014, 1, 7), account='Assets:US:BofA:Checking', position=-636.64 USD, balance=(5148.57 USD)),
#  ResultRow(date=datetime.date(2014, 1, 8), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(5083.57 USD)),
#  ResultRow(date=datetime.date(2014, 1, 16), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(6434.17 USD)),
#  ResultRow(date=datetime.date(2014, 1, 20), account='Assets:US:BofA:Checking', position=-36.85 USD, balance=(6397.32 USD)),
#  ResultRow(date=datetime.date(2014, 1, 22), account='Assets:US:BofA:Checking', position=-80.10 USD, balance=(6317.22 USD)),
#  ResultRow(date=datetime.date(2014, 1, 30), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(7667.82 USD)),
#  ResultRow(date=datetime.date(2014, 2, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(7663.82 USD)),
#  ResultRow(date=datetime.date(2014, 2, 6), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(5263.82 USD)),
#  ResultRow(date=datetime.date(2014, 2, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(5198.82 USD)),
#  ResultRow(date=datetime.date(2014, 2, 10), account='Assets:US:BofA:Checking', position=-260.24 USD, balance=(4938.58 USD)),
#  ResultRow(date=datetime.date(2014, 2, 13), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(6289.18 USD)),
#  ResultRow(date=datetime.date(2014, 2, 19), account='Assets:US:BofA:Checking', position=-80.03 USD, balance=(6209.15 USD)),
#  ResultRow(date=datetime.date(2014, 2, 21), account='Assets:US:BofA:Checking', position=-79.87 USD, balance=(6129.28 USD)),
#  ResultRow(date=datetime.date(2014, 2, 27), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(7479.88 USD)),
#  ResultRow(date=datetime.date(2014, 3, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(7475.88 USD)),
#  ResultRow(date=datetime.date(2014, 3, 5), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(5075.88 USD)),
#  ResultRow(date=datetime.date(2014, 3, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(5010.88 USD)),
#  ResultRow(date=datetime.date(2014, 3, 11), account='Assets:US:BofA:Checking', position=-538.57 USD, balance=(4472.31 USD)),
#  ResultRow(date=datetime.date(2014, 3, 13), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(5822.91 USD)),
#  ResultRow(date=datetime.date(2014, 3, 18), account='Assets:US:BofA:Checking', position=-61.52 USD, balance=(5761.39 USD)),
#  ResultRow(date=datetime.date(2014, 3, 22), account='Assets:US:BofA:Checking', position=-80.01 USD, balance=(5681.38 USD)),
#  ResultRow(date=datetime.date(2014, 3, 25), account='Assets:US:BofA:Checking', position=-425.68 USD, balance=(5255.70 USD)),
#  ResultRow(date=datetime.date(2014, 3, 27), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(6606.30 USD)),
#  ResultRow(date=datetime.date(2014, 3, 28), account='Assets:US:BofA:Checking', position=-376.64 USD, balance=(6229.66 USD)),
#  ResultRow(date=datetime.date(2014, 4, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(6225.66 USD)),
#  ResultRow(date=datetime.date(2014, 4, 4), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(3825.66 USD)),
#  ResultRow(date=datetime.date(2014, 4, 8), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(3760.66 USD)),
#  ResultRow(date=datetime.date(2014, 4, 8), account='Assets:US:BofA:Checking', position=-732.98 USD, balance=(3027.68 USD)),
#  ResultRow(date=datetime.date(2014, 4, 10), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(4378.28 USD)),
#  ResultRow(date=datetime.date(2014, 4, 18), account='Assets:US:BofA:Checking', position=-46.97 USD, balance=(4331.31 USD)),
#  ResultRow(date=datetime.date(2014, 4, 23), account='Assets:US:BofA:Checking', position=-79.95 USD, balance=(4251.36 USD)),
#  ResultRow(date=datetime.date(2014, 4, 24), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(5601.96 USD)),
#  ResultRow(date=datetime.date(2014, 5, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(5597.96 USD)),
#  ResultRow(date=datetime.date(2014, 5, 6), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(3197.96 USD)),
#  ResultRow(date=datetime.date(2014, 5, 8), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(4548.56 USD)),
#  ResultRow(date=datetime.date(2014, 5, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(4483.56 USD)),
#  ResultRow(date=datetime.date(2014, 5, 9), account='Assets:US:BofA:Checking', position=-558.58 USD, balance=(3924.98 USD)),
#  ResultRow(date=datetime.date(2014, 5, 19), account='Assets:US:BofA:Checking', position=-68.08 USD, balance=(3856.90 USD)),
#  ResultRow(date=datetime.date(2014, 5, 22), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(5207.50 USD)),
#  ResultRow(date=datetime.date(2014, 5, 23), account='Assets:US:BofA:Checking', position=-79.99 USD, balance=(5127.51 USD)),
#  ResultRow(date=datetime.date(2014, 6, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(5123.51 USD)),
#  ResultRow(date=datetime.date(2014, 6, 4), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(2723.51 USD)),
#  ResultRow(date=datetime.date(2014, 6, 5), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(4074.11 USD)),
#  ResultRow(date=datetime.date(2014, 6, 8), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(4009.11 USD)),
#  ResultRow(date=datetime.date(2014, 6, 11), account='Assets:US:BofA:Checking', position=-587.64 USD, balance=(3421.47 USD)),
#  ResultRow(date=datetime.date(2014, 6, 19), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(4772.07 USD)),
#  ResultRow(date=datetime.date(2014, 6, 20), account='Assets:US:BofA:Checking', position=-74.50 USD, balance=(4697.57 USD)),
#  ResultRow(date=datetime.date(2014, 6, 22), account='Assets:US:BofA:Checking', position=-80.18 USD, balance=(4617.39 USD)),
#  ResultRow(date=datetime.date(2014, 7, 3), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(5967.99 USD)),
#  ResultRow(date=datetime.date(2014, 7, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(5963.99 USD)),
#  ResultRow(date=datetime.date(2014, 7, 5), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(3563.99 USD)),
#  ResultRow(date=datetime.date(2014, 7, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(3498.99 USD)),
#  ResultRow(date=datetime.date(2014, 7, 9), account='Assets:US:BofA:Checking', position=-628.88 USD, balance=(2870.11 USD)),
#  ResultRow(date=datetime.date(2014, 7, 17), account='Assets:US:BofA:Checking', position=1850.60 USD, balance=(4720.71 USD)),
#  ResultRow(date=datetime.date(2014, 7, 18), account='Assets:US:BofA:Checking', position=-61.57 USD, balance=(4659.14 USD)),
#  ResultRow(date=datetime.date(2014, 7, 18), account='Assets:US:BofA:Checking', position=-3500 USD, balance=(1159.14 USD)),
#  ResultRow(date=datetime.date(2014, 7, 23), account='Assets:US:BofA:Checking', position=-80.02 USD, balance=(1079.12 USD)),
#  ResultRow(date=datetime.date(2014, 7, 31), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(3629.72 USD)),
#  ResultRow(date=datetime.date(2014, 8, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(3625.72 USD)),
#  ResultRow(date=datetime.date(2014, 8, 4), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(1225.72 USD)),
#  ResultRow(date=datetime.date(2014, 8, 8), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(1160.72 USD)),
#  ResultRow(date=datetime.date(2014, 8, 9), account='Assets:US:BofA:Checking', position=-822.26 USD, balance=(338.46 USD)),
#  ResultRow(date=datetime.date(2014, 8, 14), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(2889.06 USD)),
#  ResultRow(date=datetime.date(2014, 8, 18), account='Assets:US:BofA:Checking', position=-64.39 USD, balance=(2824.67 USD)),
#  ResultRow(date=datetime.date(2014, 8, 22), account='Assets:US:BofA:Checking', position=-80.14 USD, balance=(2744.53 USD)),
#  ResultRow(date=datetime.date(2014, 8, 28), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(5295.13 USD)),
#  ResultRow(date=datetime.date(2014, 9, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(5291.13 USD)),
#  ResultRow(date=datetime.date(2014, 9, 6), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(2891.13 USD)),
#  ResultRow(date=datetime.date(2014, 9, 8), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(2826.13 USD)),
#  ResultRow(date=datetime.date(2014, 9, 10), account='Assets:US:BofA:Checking', position=-507.02 USD, balance=(2319.11 USD)),
#  ResultRow(date=datetime.date(2014, 9, 11), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(4869.71 USD)),
#  ResultRow(date=datetime.date(2014, 9, 12), account='Assets:US:BofA:Checking', position=-4000 USD, balance=(869.71 USD)),
#  ResultRow(date=datetime.date(2014, 9, 20), account='Assets:US:BofA:Checking', position=-58.03 USD, balance=(811.68 USD)),
#  ResultRow(date=datetime.date(2014, 9, 22), account='Assets:US:BofA:Checking', position=-79.92 USD, balance=(731.76 USD)),
#  ResultRow(date=datetime.date(2014, 9, 25), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(3282.36 USD)),
#  ResultRow(date=datetime.date(2014, 10, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(3278.36 USD)),
#  ResultRow(date=datetime.date(2014, 10, 4), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(878.36 USD)),
#  ResultRow(date=datetime.date(2014, 10, 7), account='Assets:US:BofA:Checking', position=-445.77 USD, balance=(432.59 USD)),
#  ResultRow(date=datetime.date(2014, 10, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(367.59 USD)),
#  ResultRow(date=datetime.date(2014, 10, 9), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(2918.19 USD)),
#  ResultRow(date=datetime.date(2014, 10, 18), account='Assets:US:BofA:Checking', position=-58.54 USD, balance=(2859.65 USD)),
#  ResultRow(date=datetime.date(2014, 10, 21), account='Assets:US:BofA:Checking', position=-80.14 USD, balance=(2779.51 USD)),
#  ResultRow(date=datetime.date(2014, 10, 23), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(5330.11 USD)),
#  ResultRow(date=datetime.date(2014, 11, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(5326.11 USD)),
#  ResultRow(date=datetime.date(2014, 11, 5), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(2926.11 USD)),
#  ResultRow(date=datetime.date(2014, 11, 6), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(5476.71 USD)),
#  ResultRow(date=datetime.date(2014, 11, 7), account='Assets:US:BofA:Checking', position=-4000 USD, balance=(1476.71 USD)),
#  ResultRow(date=datetime.date(2014, 11, 8), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(1411.71 USD)),
#  ResultRow(date=datetime.date(2014, 11, 10), account='Assets:US:BofA:Checking', position=-813.66 USD, balance=(598.05 USD)),
#  ResultRow(date=datetime.date(2014, 11, 18), account='Assets:US:BofA:Checking', position=-58.39 USD, balance=(539.66 USD)),
#  ResultRow(date=datetime.date(2014, 11, 20), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(3090.26 USD)),
#  ResultRow(date=datetime.date(2014, 11, 23), account='Assets:US:BofA:Checking', position=-80.07 USD, balance=(3010.19 USD)),
#  ResultRow(date=datetime.date(2014, 12, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(3006.19 USD)),
#  ResultRow(date=datetime.date(2014, 12, 4), account='Assets:US:BofA:Checking', position=2589.06 USD, balance=(5595.25 USD)),
#  ResultRow(date=datetime.date(2014, 12, 5), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(3195.25 USD)),
#  ResultRow(date=datetime.date(2014, 12, 8), account='Assets:US:BofA:Checking', position=-626.58 USD, balance=(2568.67 USD)),
#  ResultRow(date=datetime.date(2014, 12, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(2503.67 USD)),
#  ResultRow(date=datetime.date(2014, 12, 18), account='Assets:US:BofA:Checking', position=-57.09 USD, balance=(2446.58 USD)),
#  ResultRow(date=datetime.date(2014, 12, 18), account='Assets:US:BofA:Checking', position=2832.14 USD, balance=(5278.72 USD)),
#  ResultRow(date=datetime.date(2014, 12, 21), account='Assets:US:BofA:Checking', position=-80.03 USD, balance=(5198.69 USD)),
#  ResultRow(date=datetime.date(2015, 1, 1), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(6549.29 USD)),
#  ResultRow(date=datetime.date(2015, 1, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(6545.29 USD)),
#  ResultRow(date=datetime.date(2015, 1, 6), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(4145.29 USD)),
#  ResultRow(date=datetime.date(2015, 1, 8), account='Assets:US:BofA:Checking', position=-576.10 USD, balance=(3569.19 USD)),
#  ResultRow(date=datetime.date(2015, 1, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(3504.19 USD)),
#  ResultRow(date=datetime.date(2015, 1, 15), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(4854.79 USD)),
#  ResultRow(date=datetime.date(2015, 1, 18), account='Assets:US:BofA:Checking', position=-59.57 USD, balance=(4795.22 USD)),
#  ResultRow(date=datetime.date(2015, 1, 21), account='Assets:US:BofA:Checking', position=-79.97 USD, balance=(4715.25 USD)),
#  ResultRow(date=datetime.date(2015, 1, 29), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(6065.85 USD)),
#  ResultRow(date=datetime.date(2015, 2, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(6061.85 USD)),
#  ResultRow(date=datetime.date(2015, 2, 4), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(3661.85 USD)),
#  ResultRow(date=datetime.date(2015, 2, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(3596.85 USD)),
#  ResultRow(date=datetime.date(2015, 2, 9), account='Assets:US:BofA:Checking', position=-800.37 USD, balance=(2796.48 USD)),
#  ResultRow(date=datetime.date(2015, 2, 12), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(4147.08 USD)),
#  ResultRow(date=datetime.date(2015, 2, 19), account='Assets:US:BofA:Checking', position=-64.14 USD, balance=(4082.94 USD)),
#  ResultRow(date=datetime.date(2015, 2, 21), account='Assets:US:BofA:Checking', position=-80.12 USD, balance=(4002.82 USD)),
#  ResultRow(date=datetime.date(2015, 2, 26), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(5353.42 USD)),
#  ResultRow(date=datetime.date(2015, 3, 3), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(2953.42 USD)),
#  ResultRow(date=datetime.date(2015, 3, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(2949.42 USD)),
#  ResultRow(date=datetime.date(2015, 3, 8), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(2884.42 USD)),
#  ResultRow(date=datetime.date(2015, 3, 8), account='Assets:US:BofA:Checking', position=-371.55 USD, balance=(2512.87 USD)),
#  ResultRow(date=datetime.date(2015, 3, 12), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(3863.47 USD)),
#  ResultRow(date=datetime.date(2015, 3, 18), account='Assets:US:BofA:Checking', position=-38.93 USD, balance=(3824.54 USD)),
#  ResultRow(date=datetime.date(2015, 3, 20), account='Assets:US:BofA:Checking', position=-378.37 USD, balance=(3446.17 USD)),
#  ResultRow(date=datetime.date(2015, 3, 22), account='Assets:US:BofA:Checking', position=-80.01 USD, balance=(3366.16 USD)),
#  ResultRow(date=datetime.date(2015, 3, 22), account='Assets:US:BofA:Checking', position=-453.36 USD, balance=(2912.80 USD)),
#  ResultRow(date=datetime.date(2015, 3, 26), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(4263.40 USD)),
#  ResultRow(date=datetime.date(2015, 4, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(4259.40 USD)),
#  ResultRow(date=datetime.date(2015, 4, 4), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(1859.40 USD)),
#  ResultRow(date=datetime.date(2015, 4, 7), account='Assets:US:BofA:Checking', position=-722.48 USD, balance=(1136.92 USD)),
#  ResultRow(date=datetime.date(2015, 4, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(1071.92 USD)),
#  ResultRow(date=datetime.date(2015, 4, 9), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(2422.52 USD)),
#  ResultRow(date=datetime.date(2015, 4, 19), account='Assets:US:BofA:Checking', position=-53.70 USD, balance=(2368.82 USD)),
#  ResultRow(date=datetime.date(2015, 4, 23), account='Assets:US:BofA:Checking', position=-80.10 USD, balance=(2288.72 USD)),
#  ResultRow(date=datetime.date(2015, 4, 23), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(3639.32 USD)),
#  ResultRow(date=datetime.date(2015, 5, 3), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(1239.32 USD)),
#  ResultRow(date=datetime.date(2015, 5, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(1235.32 USD)),
#  ResultRow(date=datetime.date(2015, 5, 7), account='Assets:US:BofA:Checking', position=-589.26 USD, balance=(646.06 USD)),
#  ResultRow(date=datetime.date(2015, 5, 7), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(1996.66 USD)),
#  ResultRow(date=datetime.date(2015, 5, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(1931.66 USD)),
#  ResultRow(date=datetime.date(2015, 5, 20), account='Assets:US:BofA:Checking', position=-66.02 USD, balance=(1865.64 USD)),
#  ResultRow(date=datetime.date(2015, 5, 21), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(3216.24 USD)),
#  ResultRow(date=datetime.date(2015, 5, 23), account='Assets:US:BofA:Checking', position=-80.09 USD, balance=(3136.15 USD)),
#  ResultRow(date=datetime.date(2015, 6, 3), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(736.15 USD)),
#  ResultRow(date=datetime.date(2015, 6, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(732.15 USD)),
#  ResultRow(date=datetime.date(2015, 6, 4), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(2082.75 USD)),
#  ResultRow(date=datetime.date(2015, 6, 8), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(2017.75 USD)),
#  ResultRow(date=datetime.date(2015, 6, 10), account='Assets:US:BofA:Checking', position=-693.08 USD, balance=(1324.67 USD)),
#  ResultRow(date=datetime.date(2015, 6, 18), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(2675.27 USD)),
#  ResultRow(date=datetime.date(2015, 6, 20), account='Assets:US:BofA:Checking', position=-67.58 USD, balance=(2607.69 USD)),
#  ResultRow(date=datetime.date(2015, 6, 23), account='Assets:US:BofA:Checking', position=-80.12 USD, balance=(2527.57 USD)),
#  ResultRow(date=datetime.date(2015, 7, 2), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(3878.17 USD)),
#  ResultRow(date=datetime.date(2015, 7, 3), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(1478.17 USD)),
#  ResultRow(date=datetime.date(2015, 7, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(1474.17 USD)),
#  ResultRow(date=datetime.date(2015, 7, 8), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(1409.17 USD)),
#  ResultRow(date=datetime.date(2015, 7, 10), account='Assets:US:BofA:Checking', position=-623.77 USD, balance=(785.40 USD)),
#  ResultRow(date=datetime.date(2015, 7, 16), account='Assets:US:BofA:Checking', position=1350.60 USD, balance=(2136.00 USD)),
#  ResultRow(date=datetime.date(2015, 7, 18), account='Assets:US:BofA:Checking', position=-58.63 USD, balance=(2077.37 USD)),
#  ResultRow(date=datetime.date(2015, 7, 22), account='Assets:US:BofA:Checking', position=-80.02 USD, balance=(1997.35 USD)),
#  ResultRow(date=datetime.date(2015, 7, 30), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(4547.95 USD)),
#  ResultRow(date=datetime.date(2015, 8, 3), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(2147.95 USD)),
#  ResultRow(date=datetime.date(2015, 8, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(2143.95 USD)),
#  ResultRow(date=datetime.date(2015, 8, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(2078.95 USD)),
#  ResultRow(date=datetime.date(2015, 8, 10), account='Assets:US:BofA:Checking', position=-712.22 USD, balance=(1366.73 USD)),
#  ResultRow(date=datetime.date(2015, 8, 13), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(3917.33 USD)),
#  ResultRow(date=datetime.date(2015, 8, 14), account='Assets:US:BofA:Checking', position=-3500 USD, balance=(417.33 USD)),
#  ResultRow(date=datetime.date(2015, 8, 19), account='Assets:US:BofA:Checking', position=-55.51 USD, balance=(361.82 USD)),
#  ResultRow(date=datetime.date(2015, 8, 21), account='Assets:US:BofA:Checking', position=-79.89 USD, balance=(281.93 USD)),
#  ResultRow(date=datetime.date(2015, 8, 27), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(2832.53 USD)),
#  ResultRow(date=datetime.date(2015, 9, 3), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(432.53 USD)),
#  ResultRow(date=datetime.date(2015, 9, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(428.53 USD)),
#  ResultRow(date=datetime.date(2015, 9, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(363.53 USD)),
#  ResultRow(date=datetime.date(2015, 9, 10), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(2914.13 USD)),
#  ResultRow(date=datetime.date(2015, 9, 11), account='Assets:US:BofA:Checking', position=-651.06 USD, balance=(2263.07 USD)),
#  ResultRow(date=datetime.date(2015, 9, 19), account='Assets:US:BofA:Checking', position=-31.27 USD, balance=(2231.80 USD)),
#  ResultRow(date=datetime.date(2015, 9, 22), account='Assets:US:BofA:Checking', position=-79.94 USD, balance=(2151.86 USD)),
#  ResultRow(date=datetime.date(2015, 9, 24), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(4702.46 USD)),
#  ResultRow(date=datetime.date(2015, 10, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(4698.46 USD)),
#  ResultRow(date=datetime.date(2015, 10, 5), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(2298.46 USD)),
#  ResultRow(date=datetime.date(2015, 10, 7), account='Assets:US:BofA:Checking', position=-494.90 USD, balance=(1803.56 USD)),
#  ResultRow(date=datetime.date(2015, 10, 8), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(4354.16 USD)),
#  ResultRow(date=datetime.date(2015, 10, 9), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(4289.16 USD)),
#  ResultRow(date=datetime.date(2015, 10, 9), account='Assets:US:BofA:Checking', position=-4000 USD, balance=(289.16 USD)),
#  ResultRow(date=datetime.date(2015, 10, 20), account='Assets:US:BofA:Checking', position=-62.86 USD, balance=(226.30 USD)),
#  ResultRow(date=datetime.date(2015, 10, 22), account='Assets:US:BofA:Checking', position=-80.11 USD, balance=(146.19 USD)),
#  ResultRow(date=datetime.date(2015, 10, 22), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(2696.79 USD)),
#  ResultRow(date=datetime.date(2015, 11, 3), account='Assets:US:BofA:Checking', position=-2400.00 USD, balance=(296.79 USD)),
#  ResultRow(date=datetime.date(2015, 11, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(292.79 USD)),
#  ResultRow(date=datetime.date(2015, 11, 5), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(2843.39 USD)),
#  ResultRow(date=datetime.date(2015, 11, 8), account='Assets:US:BofA:Checking', position=-65.00 USD, balance=(2778.39 USD)),
#  ResultRow(date=datetime.date(2015, 11, 9), account='Assets:US:BofA:Checking', position=-579.26 USD, balance=(2199.13 USD)),
#  ResultRow(date=datetime.date(2015, 11, 18), account='Assets:US:BofA:Checking', position=-43.73 USD, balance=(2155.40 USD)),
#  ResultRow(date=datetime.date(2015, 11, 19), account='Assets:US:BofA:Checking', position=2550.60 USD, balance=(4706.00 USD)),
#  ResultRow(date=datetime.date(2015, 11, 20), account='Assets:US:BofA:Checking', position=-4000 USD, balance=(706.00 USD)),
#  ResultRow(date=datetime.date(2015, 11, 22), account='Assets:US:BofA:Checking', position=-79.97 USD, balance=(626.03 USD)),
#  ResultRow(date=datetime.date(2015, 12, 3), account='Assets:US:BofA:Checking', position=2589.06 USD, balance=(3215.09 USD)),
#  ResultRow(date=datetime.date(2015, 12, 4), account='Assets:US:BofA:Checking', position=-4.00 USD, balance=(3211.09 USD)),
#  ResultRow(date=datetime.date(2015, 12, 4), account='Assets:US:BofA:Checking', position=-3000 USD, balance=(211.09 USD)),
#  ResultRow(date=datetime.date(2015, 12, 17), account='Assets:US:BofA:Checking', position=2832.14 USD, balance=(3043.23 USD))]

# %% [markdown]
# # Beancount Query Language
# Expenses for month

# %%
from beancount.query import query

query_str = r"""
SELECT 
    account, sum(cost(position)) as total, month 
WHERE
    account ~ "Expenses:*" and year = YEAR(2013-01-01) and month = MONTH(2013-01-01) 
GROUP BY month, account 
ORDER BY total, account DESC
"""
rtypes, rrows = query.run_query(entries,options_map,query_str)
rrows
# Out:
# [ResultRow(account='Expenses:Taxes:Y2013:US:Federal:PreTax401k', total=(3600.00 IRAUSD), month=1),
#  ResultRow(account='Expenses:Taxes:Y2013:US:Federal', total=(3188.76 USD), month=1),
#  ResultRow(account='Expenses:Home:Rent', total=(2400.00 USD), month=1),
#  ResultRow(account='Expenses:Taxes:Y2013:US:State', total=(1095.24 USD), month=1),
#  ResultRow(account='Expenses:Taxes:Y2013:US:SocSec', total=(844.62 USD), month=1),
#  ResultRow(account='Expenses:Taxes:Y2013:US:CityNYC', total=(524.76 USD), month=1),
#  ResultRow(account='Expenses:Taxes:Y2013:US:Medicare', total=(319.86 USD), month=1),
#  ResultRow(account='Expenses:Food:Restaurant', total=(284.47 USD), month=1),
#  ResultRow(account='Expenses:Food:Groceries', total=(241.30 USD), month=1),
#  ResultRow(account='Expenses:Health:Vision:Insurance', total=(126.90 USD), month=1),
#  ResultRow(account='Expenses:Transport:Tram', total=(120.00 USD), month=1),
#  ResultRow(account='Expenses:Health:Medical:Insurance', total=(82.14 USD), month=1),
#  ResultRow(account='Expenses:Home:Internet', total=(79.85 USD), month=1),
#  ResultRow(account='Expenses:Health:Life:GroupTermLife', total=(72.96 USD), month=1),
#  ResultRow(account='Expenses:Home:Phone', total=(69.82 USD), month=1),
#  ResultRow(account='Expenses:Home:Electricity', total=(65.00 USD), month=1),
#  ResultRow(account='Expenses:Health:Dental:Insurance', total=(8.70 USD), month=1),
#  ResultRow(account='Expenses:Financial:Fees', total=(4.00 USD), month=1),
#  ResultRow(account='Expenses:Taxes:Y2013:US:SDI', total=(3.36 USD), month=1)]

# %% [markdown]
# # Beancount Query Language
# Monthly Expense Report

# %%
from beancount.query import query

query_str = r"""
SELECT
    year, month, account, sum(position)
FROM
    date > 2013-01-01 AND date < 2015-01-01
WHERE
    account ~ "Expenses"
    GROUP BY year, month, account
    ORDER by year, month, account
"""
rtypes, rrows = query.run_query(entries,options_map,query_str)
rrows
# Out:
# [ResultRow(year=2013, month=1, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Food:Groceries', sum_position=(241.30 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Food:Restaurant', sum_position=(284.47 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Health:Dental:Insurance', sum_position=(8.70 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Health:Life:GroupTermLife', sum_position=(72.96 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Health:Medical:Insurance', sum_position=(82.14 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Health:Vision:Insurance', sum_position=(126.90 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Home:Internet', sum_position=(79.85 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Home:Phone', sum_position=(69.82 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Taxes:Y2013:US:CityNYC', sum_position=(524.76 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Taxes:Y2013:US:Federal', sum_position=(3188.76 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Taxes:Y2013:US:Federal:PreTax401k', sum_position=(3600.00 IRAUSD)),
#  ResultRow(year=2013, month=1, account='Expenses:Taxes:Y2013:US:Medicare', sum_position=(319.86 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Taxes:Y2013:US:SDI', sum_position=(3.36 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Taxes:Y2013:US:SocSec', sum_position=(844.62 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Taxes:Y2013:US:State', sum_position=(1095.24 USD)),
#  ResultRow(year=2013, month=1, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Food:Groceries', sum_position=(186.21 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Food:Restaurant', sum_position=(275.19 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Home:Internet', sum_position=(79.97 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Home:Phone', sum_position=(46.32 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Taxes:Y2013:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Taxes:Y2013:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Taxes:Y2013:US:Federal:PreTax401k', sum_position=(2400.00 IRAUSD)),
#  ResultRow(year=2013, month=2, account='Expenses:Taxes:Y2013:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Taxes:Y2013:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Taxes:Y2013:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2013, month=2, account='Expenses:Taxes:Y2013:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Food:Groceries', sum_position=(218.48 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Food:Restaurant', sum_position=(374.13 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Home:Internet', sum_position=(80.00 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Home:Phone', sum_position=(76.81 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Taxes:Y2013:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Taxes:Y2013:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Taxes:Y2013:US:Federal:PreTax401k', sum_position=(2400.00 IRAUSD)),
#  ResultRow(year=2013, month=3, account='Expenses:Taxes:Y2013:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Taxes:Y2013:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Taxes:Y2013:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Taxes:Y2013:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2013, month=3, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Food:Groceries', sum_position=(136.33 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Food:Restaurant', sum_position=(266.38 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Home:Internet', sum_position=(80.19 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Home:Phone', sum_position=(63.51 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Taxes:Y2013:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Taxes:Y2013:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Taxes:Y2013:US:Federal:PreTax401k', sum_position=(2400.00 IRAUSD)),
#  ResultRow(year=2013, month=4, account='Expenses:Taxes:Y2013:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Taxes:Y2013:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Taxes:Y2013:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Taxes:Y2013:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2013, month=4, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Food:Groceries', sum_position=(194.01 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Food:Restaurant', sum_position=(303.15 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Home:Internet', sum_position=(79.93 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Home:Phone', sum_position=(56.07 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Taxes:Y2013:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Taxes:Y2013:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Taxes:Y2013:US:Federal:PreTax401k', sum_position=(2400.00 IRAUSD)),
#  ResultRow(year=2013, month=5, account='Expenses:Taxes:Y2013:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Taxes:Y2013:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Taxes:Y2013:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Taxes:Y2013:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2013, month=5, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Food:Coffee', sum_position=(25.28 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Food:Groceries', sum_position=(57.01 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Food:Restaurant', sum_position=(617.84 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Home:Internet', sum_position=(79.86 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Home:Phone', sum_position=(59.21 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Taxes:Y2013:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Taxes:Y2013:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Taxes:Y2013:US:Federal:PreTax401k', sum_position=(2400.00 IRAUSD)),
#  ResultRow(year=2013, month=6, account='Expenses:Taxes:Y2013:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Taxes:Y2013:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Taxes:Y2013:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Taxes:Y2013:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2013, month=6, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Food:Coffee', sum_position=(12.93 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Food:Groceries', sum_position=(214.35 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Food:Restaurant', sum_position=(352.67 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Home:Internet', sum_position=(80.17 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Home:Phone', sum_position=(50.68 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Taxes:Y2013:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Taxes:Y2013:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Taxes:Y2013:US:Federal:PreTax401k', sum_position=(1900.00 IRAUSD)),
#  ResultRow(year=2013, month=7, account='Expenses:Taxes:Y2013:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Taxes:Y2013:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Taxes:Y2013:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Taxes:Y2013:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2013, month=7, account='Expenses:Vacation', sum_position=(128 VACHR)),
#  ResultRow(year=2013, month=8, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Food:Groceries', sum_position=(168.42 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Food:Restaurant', sum_position=(259.25 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Health:Dental:Insurance', sum_position=(8.70 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Health:Life:GroupTermLife', sum_position=(72.96 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Health:Medical:Insurance', sum_position=(82.14 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Health:Vision:Insurance', sum_position=(126.90 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Home:Internet', sum_position=(79.98 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Home:Phone', sum_position=(61.29 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Taxes:Y2013:US:CityNYC', sum_position=(524.76 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Taxes:Y2013:US:Federal', sum_position=(3188.76 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Taxes:Y2013:US:Medicare', sum_position=(319.86 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Taxes:Y2013:US:SDI', sum_position=(3.36 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Taxes:Y2013:US:SocSec', sum_position=(844.62 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Taxes:Y2013:US:State', sum_position=(1095.24 USD)),
#  ResultRow(year=2013, month=8, account='Expenses:Transport:Tram', sum_position=(240.00 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Financial:Commissions', sum_position=(26.85 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Food:Groceries', sum_position=(183.69 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Food:Restaurant', sum_position=(363.30 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Home:Internet', sum_position=(80.02 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Home:Phone', sum_position=(81.85 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Taxes:Y2013:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Taxes:Y2013:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Taxes:Y2013:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Taxes:Y2013:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Taxes:Y2013:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Taxes:Y2013:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2013, month=9, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Financial:Commissions', sum_position=(44.75 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Food:Groceries', sum_position=(281.28 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Food:Restaurant', sum_position=(326.50 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Home:Internet', sum_position=(79.97 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Home:Phone', sum_position=(76.78 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Taxes:Y2013:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Taxes:Y2013:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Taxes:Y2013:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Taxes:Y2013:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Taxes:Y2013:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Taxes:Y2013:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2013, month=10, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Financial:Commissions', sum_position=(17.90 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Food:Groceries', sum_position=(110.10 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Food:Restaurant', sum_position=(305.97 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Home:Internet', sum_position=(79.83 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Home:Phone', sum_position=(89.68 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Taxes:Y2013:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Taxes:Y2013:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Taxes:Y2013:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Taxes:Y2013:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Taxes:Y2013:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2013, month=11, account='Expenses:Taxes:Y2013:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Food:Groceries', sum_position=(220.59 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Food:Restaurant', sum_position=(451.64 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Home:Internet', sum_position=(79.90 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Home:Phone', sum_position=(39.70 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Taxes:Y2013:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Taxes:Y2013:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Taxes:Y2013:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Taxes:Y2013:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Taxes:Y2013:US:SocSec', sum_position=(243.08 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Taxes:Y2013:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2013, month=12, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Food:Coffee', sum_position=(22.77 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Food:Groceries', sum_position=(146.84 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Food:Restaurant', sum_position=(545.43 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Health:Dental:Insurance', sum_position=(8.70 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Health:Life:GroupTermLife', sum_position=(72.96 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Health:Medical:Insurance', sum_position=(82.14 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Health:Vision:Insurance', sum_position=(126.90 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Home:Internet', sum_position=(80.10 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Home:Phone', sum_position=(36.85 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Taxes:Y2014:US:CityNYC', sum_position=(524.76 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Taxes:Y2014:US:Federal', sum_position=(3188.76 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Taxes:Y2014:US:Federal:PreTax401k', sum_position=(3600.00 IRAUSD)),
#  ResultRow(year=2014, month=1, account='Expenses:Taxes:Y2014:US:Medicare', sum_position=(319.86 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Taxes:Y2014:US:SDI', sum_position=(3.36 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Taxes:Y2014:US:SocSec', sum_position=(844.62 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Taxes:Y2014:US:State', sum_position=(1095.24 USD)),
#  ResultRow(year=2014, month=1, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Food:Coffee', sum_position=(93.20 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Food:Groceries', sum_position=(93.86 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Food:Restaurant', sum_position=(788.71 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Home:Internet', sum_position=(79.87 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Home:Phone', sum_position=(80.03 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Taxes:Y2014:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Taxes:Y2014:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Taxes:Y2014:US:Federal:PreTax401k', sum_position=(2400.00 IRAUSD)),
#  ResultRow(year=2014, month=2, account='Expenses:Taxes:Y2014:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Taxes:Y2014:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Taxes:Y2014:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Taxes:Y2014:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2014, month=2, account='Expenses:Vacation', sum_position=(160 VACHR)),
#  ResultRow(year=2014, month=3, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Food:Groceries', sum_position=(179.30 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Food:Restaurant', sum_position=(276.14 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Home:Internet', sum_position=(80.01 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Home:Phone', sum_position=(61.52 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Taxes:Y2013:US:Federal', sum_position=(425.68 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Taxes:Y2013:US:State', sum_position=(376.64 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Taxes:Y2014:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Taxes:Y2014:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Taxes:Y2014:US:Federal:PreTax401k', sum_position=(2400.00 IRAUSD)),
#  ResultRow(year=2014, month=3, account='Expenses:Taxes:Y2014:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Taxes:Y2014:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Taxes:Y2014:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Taxes:Y2014:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2014, month=3, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Financial:Commissions', sum_position=(8.95 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Food:Groceries', sum_position=(237.31 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Food:Restaurant', sum_position=(410.23 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Home:Internet', sum_position=(79.95 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Home:Phone', sum_position=(46.97 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Taxes:Y2014:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Taxes:Y2014:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Taxes:Y2014:US:Federal:PreTax401k', sum_position=(2400.00 IRAUSD)),
#  ResultRow(year=2014, month=4, account='Expenses:Taxes:Y2014:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Taxes:Y2014:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Taxes:Y2014:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Taxes:Y2014:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2014, month=4, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Financial:Commissions', sum_position=(89.50 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Food:Groceries', sum_position=(213.25 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Food:Restaurant', sum_position=(286.09 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Home:Internet', sum_position=(79.99 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Home:Phone', sum_position=(68.08 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Taxes:Y2014:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Taxes:Y2014:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Taxes:Y2014:US:Federal:PreTax401k', sum_position=(2400.00 IRAUSD)),
#  ResultRow(year=2014, month=5, account='Expenses:Taxes:Y2014:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Taxes:Y2014:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Taxes:Y2014:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Taxes:Y2014:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2014, month=5, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Food:Groceries', sum_position=(158.25 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Food:Restaurant', sum_position=(341.71 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Home:Internet', sum_position=(80.18 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Home:Phone', sum_position=(74.50 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Taxes:Y2014:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Taxes:Y2014:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Taxes:Y2014:US:Federal:PreTax401k', sum_position=(2400.00 IRAUSD)),
#  ResultRow(year=2014, month=6, account='Expenses:Taxes:Y2014:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Taxes:Y2014:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Taxes:Y2014:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Taxes:Y2014:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2014, month=6, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Food:Groceries', sum_position=(262.36 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Food:Restaurant', sum_position=(386.74 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Health:Dental:Insurance', sum_position=(8.70 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Health:Life:GroupTermLife', sum_position=(72.96 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Health:Medical:Insurance', sum_position=(82.14 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Health:Vision:Insurance', sum_position=(126.90 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Home:Internet', sum_position=(80.02 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Home:Phone', sum_position=(61.57 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Taxes:Y2014:US:CityNYC', sum_position=(524.76 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Taxes:Y2014:US:Federal', sum_position=(3188.76 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Taxes:Y2014:US:Federal:PreTax401k', sum_position=(1900.00 IRAUSD)),
#  ResultRow(year=2014, month=7, account='Expenses:Taxes:Y2014:US:Medicare', sum_position=(319.86 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Taxes:Y2014:US:SDI', sum_position=(3.36 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Taxes:Y2014:US:SocSec', sum_position=(844.62 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Taxes:Y2014:US:State', sum_position=(1095.24 USD)),
#  ResultRow(year=2014, month=7, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Financial:Commissions', sum_position=(35.80 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Food:Groceries', sum_position=(85.38 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Food:Restaurant', sum_position=(397.64 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Home:Internet', sum_position=(80.14 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Home:Phone', sum_position=(64.39 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Taxes:Y2014:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Taxes:Y2014:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Taxes:Y2014:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Taxes:Y2014:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Taxes:Y2014:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Taxes:Y2014:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2014, month=8, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Financial:Commissions', sum_position=(17.90 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Food:Groceries', sum_position=(203.86 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Food:Restaurant', sum_position=(221.01 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Home:Internet', sum_position=(79.92 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Home:Phone', sum_position=(58.03 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Taxes:Y2014:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Taxes:Y2014:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Taxes:Y2014:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Taxes:Y2014:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Taxes:Y2014:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Taxes:Y2014:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2014, month=9, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Food:Groceries', sum_position=(352.22 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Food:Restaurant', sum_position=(271.15 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Home:Internet', sum_position=(80.14 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Home:Phone', sum_position=(58.54 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Taxes:Y2014:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Taxes:Y2014:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Taxes:Y2014:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Taxes:Y2014:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Taxes:Y2014:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Taxes:Y2014:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2014, month=10, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Financial:Commissions', sum_position=(17.90 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Food:Groceries', sum_position=(177.33 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Food:Restaurant', sum_position=(368.98 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Home:Internet', sum_position=(80.07 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Home:Phone', sum_position=(58.39 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Taxes:Y2014:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Taxes:Y2014:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Taxes:Y2014:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Taxes:Y2014:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Taxes:Y2014:US:SocSec', sum_position=(563.08 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Taxes:Y2014:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2014, month=11, account='Expenses:Transport:Tram', sum_position=(120.00 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Financial:Commissions', sum_position=(35.80 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Financial:Fees', sum_position=(4.00 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Food:Groceries', sum_position=(131.80 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Food:Restaurant', sum_position=(314.39 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Health:Dental:Insurance', sum_position=(5.80 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Health:Life:GroupTermLife', sum_position=(48.64 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Health:Medical:Insurance', sum_position=(54.76 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Health:Vision:Insurance', sum_position=(84.60 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Home:Electricity', sum_position=(65.00 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Home:Internet', sum_position=(80.03 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Home:Phone', sum_position=(57.09 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Home:Rent', sum_position=(2400.00 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Taxes:Y2014:US:CityNYC', sum_position=(349.84 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Taxes:Y2014:US:Federal', sum_position=(2125.84 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Taxes:Y2014:US:Medicare', sum_position=(213.24 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Taxes:Y2014:US:SDI', sum_position=(2.24 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Taxes:Y2014:US:SocSec', sum_position=(243.08 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Taxes:Y2014:US:State', sum_position=(730.16 USD)),
#  ResultRow(year=2014, month=12, account='Expenses:Transport:Tram', sum_position=(120.00 USD))]

# %% [markdown]
# ## Fava ~1 min
#
# * show Income Statement
# * show Balance
# * mention Journal and Query
# * show Commodities

# %% [markdown]
# all the features build up to feature that draws people to beancount, fava
#
# fava uses all these queries and processing of the data to show it visually

# %% [markdown]
# # Resources
#
# * Beancount Github Repo [https://github.com/beancount/beancount](https://github.com/beancount/beancount)
# * Beancount Docs [https://beancount.github.io/docs](https://beancount.github.io/docs)
# * Beancount Mailing List [https://groups.google.com/forum/#!forum/beancount](https://groups.google.com/forum/#!forum/beancount)
# * Fava Github Repo [https://github.com/beancount/fava](https://github.com/beancount/fava)
# * plaintext accounting site [https://plaintextaccounting.org](https://plaintextaccounting.org)
#
# ## Plugging some projects I am working on
# * Beancount/Fava Envelope Budget Plugin [https://github.com/bryall/fava-envelope](https://github.com/bryall/fava-envelope)
# * Beancount Language Server Protocol(LSP) [https://github.com/bryall/beancount-language-server](https://github.com/bryall/beancount-language-server)
